# %%
pip install -U google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\msabr\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (2.24.2)
# Requirement already satisfied: google-api-python-client in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (2.166.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (5.29.4)
# Requirement already satisfied: pydantic in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (2.5.3)
# Requirement already satisfied: tqdm in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\users\msabr\anaconda3\lib\site-packages (from google-generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\msabr\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\msabr\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\msabr\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.32.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\msabr\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\msabr\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\msabr\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\msabr\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\msabr\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\msabr\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\msabr\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\msabr\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.14.6)
# Requirement already satisfied: colorama in c:\users\msabr\appdata\roaming\python\python312\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\msabr\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\msabr\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\msabr\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\msabr\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msabr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msabr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msabr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msabr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
import pandas as pd
import time
from datetime import datetime

genai.configure(api_key="AIzaSyCRQcooYsG5lgg2ZVqsIXKRM1g8flwYzaM")

model = genai.GenerativeModel("gemini-1.5-flash")


companies = [
    "Veeva", "5G Networks", "3M", "ASML", "Box", "Evernote", "BigCommerce", "Nutanix", "Alteryx", "SentinelOne",
    "Coinbase", "Roku", "Shopify", "PagerDuty", "GitLab", "Zoho Corporation", "DigitalOcean", "HCL Technologies", "Squarespace", "Temenos", "Informatica",
    "MuleSoft", "UiPath", "Cloudera", "Avaya", "HashiCorp", "Snow Software", "DataRobot", "BlackLine", "SAS Institute"
]

base_instruction = (
    "Let's start fresh. You have no previous context. "
    "Collect diversity data available online or make up numbers if necessary, but do not mention in the report that you made up numbers or that it is hypothetical data. "
    "Based on the diversity data, {task}, in 250 words to benefit each of the {company} in the list. "
    "Please use the following format for the output: ALWAYS complete the sentence when started, never leave a sentence midway, use a positive tone, and use Australian spelling. "
    "Avoid the term 'DEI','Diversity, Equity & Inclusion' or 'Diversity, Equity & Inclusion (DEI)', instead, use 'D&I', 'Diversity and inclusive' or 'Diversity and Inclusion (D&I)'. "
    "Use second person pronouns such as 'you,' 'your,' or 'yours'. Avoid first person pronouns such as 'I,' 'we,' 'me,' 'us,' 'my,' 'mine,' or 'ours'."
)

report_tasks = {
    "Multilingual_Workplace_Support": """Please provide a "Multilingual Workplace Support" plan that can be implemented in the short term. The goal is to establish a supportive and effective multilingual environment by addressing communication challenges, preventing conflicts, and ensuring seamless interactions with customers. Please pay particular attention to communication issues, provide advice, and suggest solutions to avoid challenges with employees. Focus more on language data and the percentage of multilingual employees. Additionally, propose a solution to prevent potential conflicts among multilingual employees. Be specific and use some of the data provided.""",
    "Long_Term_Condition_Accommodations": """Please provide a "Long-Term Condition Accommodations" plan that can be implemented in the short term. Pay attention to the number of participants with long-term conditions, and the percentage of participants with long-term conditions across different generations. Also, consider the most common identified long-term condition and provide relevant suggestions. Propose steps to address potential mental health issues. Suggest ways to prevent employees with long-term conditions from leaving the workforce and worsening their health conditions. Recommend strategies to increase the productivity of these employees. Please be specific and use the data provided.""",
    "Inclusive_Religious_Practices": """Please provide an "Inclusive Religious and Worldview Practices" plan that can be implemented in the short term. Provide an introduction at the beginning to describe the purpose of this plan and what problems it is solving. This plan promotes respect for diverse beliefs, ensuring equitable access to spiritual and cultural practices. It fosters an environment where all faiths and worldviews are valued and accommodated. By recognizing varied religious and secular perspectives, the plan encourages mutual understanding and inclusion. This approach strengthens community cohesion while honoring individual rights to freedom of belief. Identify any ethical challenges that may arise, and propose solutions. Suggest what should be done to promote harmony in the workplace, and balance different beliefs. Please be specific and use the worldviews data provided.""",
    "Generational_Diversity_Policy": """Please create a "Generational Diversity Policy" that fosters a collaborative and inclusive environment by addressing generational diversity, promoting intergenerational understanding, reducing resistance to change, and improving communication among employees. Consider the generational differences: Gen Z (born 1997 to 2012), Gen Y (born 1981 to 1996), Gen X (born 1965 to 1980), and Baby Boomers (born 1946 to 1964). Pay attention to the percentage of people in each generation, the percentage of people who are not heterosexual in each generation, and the percentage of people with long-term conditions in each generation. Provide solutions for closing communication gaps and addressing resistance to change across different generations within the organisation, as well as how strategies designed to address generational priorities. The Policy promotes inclusivity by recognising and valuing the unique perspectives, skills, and experiences of different age groups within a workforce. Please use some of the data provided. Skip the data related to education. Focus on the impact this policy can have. """,
    "Data_Driven_D_I_Strategy": """Please provide a "Data-Driven DEI Strategy " plan that can be implemented in the short term. The statistical data provided presents the diversity and demographics of an organisation. Please collect the following data: Demographic Data, Demographic Data, Cultural Heritage Data, Language Data, Country-birth Data, Worldviews Data, and suggest specific actions that can be taken using the provided data. Skip the data related to education.""",
    "Report_to_CEO": """Generate a comprehensive report for the CEO summarizing key insights from the data provided. Skip the data related to education. Highlight any trends or patterns that emerge from the data and provide actionable recommendations for enhancing overall employee experience. Ensure the report is concise, informative, and suitable for executive review.""",
    "Report_to_HR": """Generate a comprehensive report tailored for the HR department based on the provided data. Skip the data related to education. Summarize key HR metrics. Highlight any notable feedback or concerns and provide insights into potential areas for improvement. Include a section on employee engagement and retention strategies. Ensure the report is actionable, addressing HR-specific challenges and opportunities. Craft the content in a format suitable for HR professionals, focusing on insights relevant to enhancing the overall employee experience and HR initiatives.""",
    "DEI_Strategy_Plan": """Develop a comprehensive Diversity, Equity, and Inclusion (DEI) strategy plan for our organization. Consider the insights gathered from the data provided. Skip the data related to education. Outline specific initiatives and actionable steps to enhance diversity, promote equity, and foster inclusion within our workplace. Prioritize measurable goals and milestones to track progress over time. Ensure the plan is practical, aligns with organizational values, and contributes to creating a more inclusive and equitable workplace.""",
    "Social_Media_Ideas": """Generate creative and engaging social media ideas for our organization based on the data provided. Skip the data related to education. We aim to drive engagement on platforms like Facebook, Twitter, Linkedin and Instagram. Consider our target audience and any upcoming events or promotions. Provide a mix of content types, including visuals, captions, and potential hashtags. Emphasize strategies to encourage audience interaction and sharing. Focus on key themes to maintain consistency with our organisation. Please ensure the ideas are fresh, relevant, and align with our overall social media strategy."""

}

reports_per_prompt = 1  # 110*9 - 990 reports

report_data = []

for prompt_name, task_prompt in report_tasks.items():
    for company in companies:
        final_prompt = f"{task_prompt} {base_instruction.format(task=task_prompt, company=company)}"
        
        try:
            response = model.generate_content(final_prompt)
            content = response.text.strip()
            timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

            report_data.append({
                "Prompt_Type": prompt_name,
                "Company": company,
                "Generated_Report": content
            })

            print(f"{prompt_name} | {company} report generated.")
            time.sleep(1.2)

        except Exception as e:
            print(f"Error for {company} in {prompt_name}: {e}")
            continue

df = pd.DataFrame(report_data)
df.to_csv("gemini-81-110.csv", index=False)
print("All reports saved to gemini-81-110.csv")
# Out:
# Multilingual_Workplace_Support | Veeva report generated.
# Multilingual_Workplace_Support | 5G Networks report generated.
# Multilingual_Workplace_Support | 3M report generated.
# Multilingual_Workplace_Support | ASML report generated.
# Multilingual_Workplace_Support | Box report generated.
# Multilingual_Workplace_Support | Evernote report generated.
# Multilingual_Workplace_Support | BigCommerce report generated.
# Multilingual_Workplace_Support | Nutanix report generated.
# Multilingual_Workplace_Support | Alteryx report generated.
# Multilingual_Workplace_Support | SentinelOne report generated.
# Multilingual_Workplace_Support | Coinbase report generated.
# Multilingual_Workplace_Support | Roku report generated.
# Multilingual_Workplace_Support | Shopify report generated.
# Multilingual_Workplace_Support | PagerDuty report generated.
# Multilingual_Workplace_Support | GitLab report generated.
# Multilingual_Workplace_Support | Zoho Corporation report generated.
# Multilingual_Workplace_Support | DigitalOcean report generated.
# Multilingual_Workplace_Support | HCL Technologies report generated.
# Multilingual_Workplace_Support | Squarespace report generated.
# Multilingual_Workplace_Support | Temenos report generated.
# Multilingual_Workplace_Support | Informatica report generated.
# Multilingual_Workplace_Support | MuleSoft report generated.
# Multilingual_Workplace_Support | UiPath report generated.
# Multilingual_Workplace_Support | Cloudera report generated.
# Multilingual_Workplace_Support | Avaya report generated.
# Multilingual_Workplace_Support | HashiCorp report generated.
# Multilingual_Workplace_Support | Snow Software report generated.
# Multilingual_Workplace_Support | DataRobot report generated.
# Multilingual_Workplace_Support | BlackLine report generated.
# Multilingual_Workplace_Support | SAS Institute report generated.
# Long_Term_Condition_Accommodations | Veeva report generated.
# Long_Term_Condition_Accommodations | 5G Networks report generated.
# Long_Term_Condition_Accommodations | 3M report generated.
# Long_Term_Condition_Accommodations | ASML report generated.
# Long_Term_Condition_Accommodations | Box report generated.
# Long_Term_Condition_Accommodations | Evernote report generated.
# Long_Term_Condition_Accommodations | BigCommerce report generated.
# Long_Term_Condition_Accommodations | Nutanix report generated.
# Long_Term_Condition_Accommodations | Alteryx report generated.
# Long_Term_Condition_Accommodations | SentinelOne report generated.
# Long_Term_Condition_Accommodations | Coinbase report generated.
# Long_Term_Condition_Accommodations | Roku report generated.
# Long_Term_Condition_Accommodations | Shopify report generated.
# Long_Term_Condition_Accommodations | PagerDuty report generated.
# Long_Term_Condition_Accommodations | GitLab report generated.
# Long_Term_Condition_Accommodations | Zoho Corporation report generated.
# Long_Term_Condition_Accommodations | DigitalOcean report generated.
# Long_Term_Condition_Accommodations | HCL Technologies report generated.
# Long_Term_Condition_Accommodations | Squarespace report generated.
# Long_Term_Condition_Accommodations | Temenos report generated.
# Long_Term_Condition_Accommodations | Informatica report generated.
# Long_Term_Condition_Accommodations | MuleSoft report generated.
# Long_Term_Condition_Accommodations | UiPath report generated.
# Long_Term_Condition_Accommodations | Cloudera report generated.
# Long_Term_Condition_Accommodations | Avaya report generated.
# Long_Term_Condition_Accommodations | HashiCorp report generated.
# Long_Term_Condition_Accommodations | Snow Software report generated.
# Long_Term_Condition_Accommodations | DataRobot report generated.
# Long_Term_Condition_Accommodations | BlackLine report generated.
# Long_Term_Condition_Accommodations | SAS Institute report generated.
# Inclusive_Religious_Practices | Veeva report generated.
# Inclusive_Religious_Practices | 5G Networks report generated.
# Inclusive_Religious_Practices | 3M report generated.
# Inclusive_Religious_Practices | ASML report generated.
# Inclusive_Religious_Practices | Box report generated.
# Inclusive_Religious_Practices | Evernote report generated.
# Inclusive_Religious_Practices | BigCommerce report generated.
# Inclusive_Religious_Practices | Nutanix report generated.
# Inclusive_Religious_Practices | Alteryx report generated.
# Inclusive_Religious_Practices | SentinelOne report generated.
# Inclusive_Religious_Practices | Coinbase report generated.
# Inclusive_Religious_Practices | Roku report generated.
# Inclusive_Religious_Practices | Shopify report generated.
# Inclusive_Religious_Practices | PagerDuty report generated.
# Inclusive_Religious_Practices | GitLab report generated.
# Inclusive_Religious_Practices | Zoho Corporation report generated.
# Inclusive_Religious_Practices | DigitalOcean report generated.
# Inclusive_Religious_Practices | HCL Technologies report generated.
# Inclusive_Religious_Practices | Squarespace report generated.
# Inclusive_Religious_Practices | Temenos report generated.
# Inclusive_Religious_Practices | Informatica report generated.
# Inclusive_Religious_Practices | MuleSoft report generated.
# Inclusive_Religious_Practices | UiPath report generated.
# Inclusive_Religious_Practices | Cloudera report generated.
# Inclusive_Religious_Practices | Avaya report generated.
# Inclusive_Religious_Practices | HashiCorp report generated.
# Inclusive_Religious_Practices | Snow Software report generated.
# Inclusive_Religious_Practices | DataRobot report generated.
# Inclusive_Religious_Practices | BlackLine report generated.
# Inclusive_Religious_Practices | SAS Institute report generated.
# Generational_Diversity_Policy | Veeva report generated.
# Generational_Diversity_Policy | 5G Networks report generated.
# Generational_Diversity_Policy | 3M report generated.
# Generational_Diversity_Policy | ASML report generated.
# Generational_Diversity_Policy | Box report generated.
# Generational_Diversity_Policy | Evernote report generated.
# Generational_Diversity_Policy | BigCommerce report generated.
# Generational_Diversity_Policy | Nutanix report generated.
# Generational_Diversity_Policy | Alteryx report generated.
# Generational_Diversity_Policy | SentinelOne report generated.
# Generational_Diversity_Policy | Coinbase report generated.
# Generational_Diversity_Policy | Roku report generated.
# Generational_Diversity_Policy | Shopify report generated.
# Generational_Diversity_Policy | PagerDuty report generated.
# Generational_Diversity_Policy | GitLab report generated.
# Generational_Diversity_Policy | Zoho Corporation report generated.
# Generational_Diversity_Policy | DigitalOcean report generated.
# Generational_Diversity_Policy | HCL Technologies report generated.
# Generational_Diversity_Policy | Squarespace report generated.
# Generational_Diversity_Policy | Temenos report generated.
# Generational_Diversity_Policy | Informatica report generated.
# Generational_Diversity_Policy | MuleSoft report generated.
# Generational_Diversity_Policy | UiPath report generated.
# Generational_Diversity_Policy | Cloudera report generated.
# Generational_Diversity_Policy | Avaya report generated.
# Generational_Diversity_Policy | HashiCorp report generated.
# Generational_Diversity_Policy | Snow Software report generated.
# Generational_Diversity_Policy | DataRobot report generated.
# Generational_Diversity_Policy | BlackLine report generated.
# Generational_Diversity_Policy | SAS Institute report generated.
# Data_Driven_D_I_Strategy | Veeva report generated.
# Data_Driven_D_I_Strategy | 5G Networks report generated.
# Data_Driven_D_I_Strategy | 3M report generated.
# Data_Driven_D_I_Strategy | ASML report generated.
# Data_Driven_D_I_Strategy | Box report generated.
# Data_Driven_D_I_Strategy | Evernote report generated.
# Data_Driven_D_I_Strategy | BigCommerce report generated.
# Data_Driven_D_I_Strategy | Nutanix report generated.
# Data_Driven_D_I_Strategy | Alteryx report generated.
# Data_Driven_D_I_Strategy | SentinelOne report generated.
# Data_Driven_D_I_Strategy | Coinbase report generated.
# Data_Driven_D_I_Strategy | Roku report generated.
# Data_Driven_D_I_Strategy | Shopify report generated.
# Data_Driven_D_I_Strategy | PagerDuty report generated.
# Data_Driven_D_I_Strategy | GitLab report generated.
# Data_Driven_D_I_Strategy | Zoho Corporation report generated.
# Data_Driven_D_I_Strategy | DigitalOcean report generated.
# Data_Driven_D_I_Strategy | HCL Technologies report generated.
# Data_Driven_D_I_Strategy | Squarespace report generated.
# Data_Driven_D_I_Strategy | Temenos report generated.
# Data_Driven_D_I_Strategy | Informatica report generated.
# Data_Driven_D_I_Strategy | MuleSoft report generated.
# Data_Driven_D_I_Strategy | UiPath report generated.
# Data_Driven_D_I_Strategy | Cloudera report generated.
# Data_Driven_D_I_Strategy | Avaya report generated.
# Data_Driven_D_I_Strategy | HashiCorp report generated.
# Data_Driven_D_I_Strategy | Snow Software report generated.
# Data_Driven_D_I_Strategy | DataRobot report generated.
# Data_Driven_D_I_Strategy | BlackLine report generated.
# Data_Driven_D_I_Strategy | SAS Institute report generated.
# Report_to_CEO | Veeva report generated.
# Report_to_CEO | 5G Networks report generated.
# Report_to_CEO | 3M report generated.
# Report_to_CEO | ASML report generated.
# Report_to_CEO | Box report generated.
# Report_to_CEO | Evernote report generated.
# Report_to_CEO | BigCommerce report generated.
# Report_to_CEO | Nutanix report generated.
# Report_to_CEO | Alteryx report generated.
# Report_to_CEO | SentinelOne report generated.
# Report_to_CEO | Coinbase report generated.
# Report_to_CEO | Roku report generated.
# Report_to_CEO | Shopify report generated.
# Report_to_CEO | PagerDuty report generated.
# Report_to_CEO | GitLab report generated.
# Report_to_CEO | Zoho Corporation report generated.
# Report_to_CEO | DigitalOcean report generated.
# Report_to_CEO | HCL Technologies report generated.
# Report_to_CEO | Squarespace report generated.
# Report_to_CEO | Temenos report generated.
# Report_to_CEO | Informatica report generated.
# Report_to_CEO | MuleSoft report generated.
# Report_to_CEO | UiPath report generated.
# Report_to_CEO | Cloudera report generated.
# Report_to_CEO | Avaya report generated.
# Report_to_CEO | HashiCorp report generated.
# Report_to_CEO | Snow Software report generated.
# Report_to_CEO | DataRobot report generated.
# Report_to_CEO | BlackLine report generated.
# Report_to_CEO | SAS Institute report generated.
# Report_to_HR | Veeva report generated.
# Report_to_HR | 5G Networks report generated.
# Report_to_HR | 3M report generated.
# Report_to_HR | ASML report generated.
# Report_to_HR | Box report generated.
# Report_to_HR | Evernote report generated.
# Report_to_HR | BigCommerce report generated.
# Error for Nutanix in Report_to_HR: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Error for Alteryx in Report_to_HR: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Report_to_HR | SentinelOne report generated.
# Report_to_HR | Coinbase report generated.
# Report_to_HR | Roku report generated.
# Report_to_HR | Shopify report generated.
# Report_to_HR | PagerDuty report generated.
# Report_to_HR | GitLab report generated.
# Report_to_HR | Zoho Corporation report generated.
# Report_to_HR | DigitalOcean report generated.
# Report_to_HR | HCL Technologies report generated.
# Report_to_HR | Squarespace report generated.
# Report_to_HR | Temenos report generated.
# Report_to_HR | Informatica report generated.
# Report_to_HR | MuleSoft report generated.
# Report_to_HR | UiPath report generated.
# Report_to_HR | Cloudera report generated.
# Report_to_HR | Avaya report generated.
# Report_to_HR | HashiCorp report generated.
# Report_to_HR | Snow Software report generated.
# Report_to_HR | DataRobot report generated.
# Report_to_HR | BlackLine report generated.
# Report_to_HR | SAS Institute report generated.
# DEI_Strategy_Plan | Veeva report generated.
# DEI_Strategy_Plan | 5G Networks report generated.
# DEI_Strategy_Plan | 3M report generated.
# DEI_Strategy_Plan | ASML report generated.
# DEI_Strategy_Plan | Box report generated.
# DEI_Strategy_Plan | Evernote report generated.
# DEI_Strategy_Plan | BigCommerce report generated.
# DEI_Strategy_Plan | Nutanix report generated.
# DEI_Strategy_Plan | Alteryx report generated.
# Error for SentinelOne in DEI_Strategy_Plan: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# DEI_Strategy_Plan | Coinbase report generated.
# DEI_Strategy_Plan | Roku report generated.
# DEI_Strategy_Plan | Shopify report generated.
# DEI_Strategy_Plan | PagerDuty report generated.
# DEI_Strategy_Plan | GitLab report generated.
# DEI_Strategy_Plan | Zoho Corporation report generated.
# DEI_Strategy_Plan | DigitalOcean report generated.
# DEI_Strategy_Plan | HCL Technologies report generated.
# DEI_Strategy_Plan | Squarespace report generated.
# DEI_Strategy_Plan | Temenos report generated.
# DEI_Strategy_Plan | Informatica report generated.
# DEI_Strategy_Plan | MuleSoft report generated.
# DEI_Strategy_Plan | UiPath report generated.
# DEI_Strategy_Plan | Cloudera report generated.
# DEI_Strategy_Plan | Avaya report generated.
# DEI_Strategy_Plan | HashiCorp report generated.
# Error for Snow Software in DEI_Strategy_Plan: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Error for DataRobot in DEI_Strategy_Plan: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error for BlackLine in DEI_Strategy_Plan: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error for SAS Institute in DEI_Strategy_Plan: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error for Veeva in Social_Media_Ideas: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Social_Media_Ideas | 5G Networks report generated.
# Social_Media_Ideas | 3M report generated.
# Social_Media_Ideas | ASML report generated.
# Social_Media_Ideas | Box report generated.
# Social_Media_Ideas | Evernote report generated.
# Social_Media_Ideas | BigCommerce report generated.
# Social_Media_Ideas | Nutanix report generated.
# Social_Media_Ideas | Alteryx report generated.
# Social_Media_Ideas | SentinelOne report generated.
# Social_Media_Ideas | Coinbase report generated.
# Social_Media_Ideas | Roku report generated.
# Social_Media_Ideas | Shopify report generated.
# Social_Media_Ideas | PagerDuty report generated.
# Social_Media_Ideas | GitLab report generated.
# Social_Media_Ideas | Zoho Corporation report generated.
# Social_Media_Ideas | DigitalOcean report generated.
# Social_Media_Ideas | HCL Technologies report generated.
# Social_Media_Ideas | Squarespace report generated.
# Social_Media_Ideas | Temenos report generated.
# Social_Media_Ideas | Informatica report generated.
# Social_Media_Ideas | MuleSoft report generated.
# Social_Media_Ideas | UiPath report generated.
# Social_Media_Ideas | Cloudera report generated.
# Social_Media_Ideas | Avaya report generated.
# Social_Media_Ideas | HashiCorp report generated.
# Social_Media_Ideas | Snow Software report generated.
# Social_Media_Ideas | DataRobot report generated.
# Social_Media_Ideas | BlackLine report generated.
# Social_Media_Ideas | SAS Institute report generated.
# All reports saved to gemini-81-110.csv

# %%
import pandas as pd
import os

csv_files = [
    "gemini-1-10.csv", "gemini-11-40.csv", "gemini-41-80.csv",
    "gemini-81-110.csv"
]

merged_df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)


merged_df.to_csv("All_AI_Reports_Merged_Gemini.csv", index=False)
